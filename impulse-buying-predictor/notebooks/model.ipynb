# %%
import warnings
warnings.filterwarnings("ignore")

from pathlib import Path
import json
import joblib
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from sklearn.feature_selection import f_regression, chi2
from sklearn.preprocessing import LabelEncoder

from lightgbm import LGBMRegressor

# %%
# Paths (Notebook-safe)
BASE_DIR = Path.cwd()
DATA_DIR = BASE_DIR / "data"
MODEL_DIR = BASE_DIR / "models"
MODEL_DIR.mkdir(exist_ok=True)

MODEL_OUT = MODEL_DIR / "lgbm_pipeline.joblib"

RANDOM_SEED = 42
TEST_SIZE = 0.2
VAL_SIZE = 0.25

# %%
df = pd.read_csv("data.csv")
df.head()
# Out:
#    user_id  age  monthly_income  account_age_days  gender  \
# 0        1   26    34371.207904               842  Female
# 1        2   53    15657.516054               985    Male
# 2        3   23    29061.244738               556  Female
# 3        4   41    66152.011773              1879    Male
# 4        5   43    52571.787230               172    Male
#
#   default_payment_method       city  total_sessions  num_product_page_visits  \
# 0                    UPI     Mumbai             101                       36
# 1                    UPI      Delhi              89                       41
# 2                   Card  Bengaluru              93                       54
# 3                   Card  Bengaluru             103                       43
# 4                    UPI    Kolkata              99                       40
#
#    num_cart_visits  ...  total_spent  avg_purchase_value  avg_discount_used  \
# 0               11  ...  8205.970287         2735.323429          13.333333
# 1                9  ...     0.000000            0.000000           0.000000
# 2                9  ...   774.538968          774.538968          50.000000
# 3                6  ...     0.000000            0.000000           0.000000
# 4               12  ...     0.000000            0.000000           0.000000
#
#   impulse_purchase_ratio  past_impulse_purchases  avg_minutes_to_purchase  \
# 0                    0.0                     0.0               105.333333
# 1                    0.0                     0.0                 0.000000
# 2                    0.0                     0.0               256.000000
# 3                    0.0                     0.0                 0.000000
# 4                    0.0                     0.0                 0.000000
#
#    stress_level  mood_last_week  saving_habit_score  impulse_buy_score
# 0      5.205191             Sad                   3              31.29
# 1      5.892735         Neutral                   5              26.97
# 2      4.491991         Neutral                   5              28.48
# 3      3.486099         Neutral                   3              18.49
# 4      6.550978         Anxious                   5              26.74
#
# [5 rows x 25 columns]

# %%
MOOD_MAPPING = {
    "Happy": 1,
    "Neutral": 2,
    "Anxious": 3,
    "Sad": 4
}

df["mood_last_week"] = df["mood_last_week"].map(MOOD_MAPPING)

# %%
target = "impulse_buy_score"

X = df.drop(columns=[target, "user_id"], errors="ignore")
y = df[target]

X_num = X.select_dtypes(include="number")

f_scores, p_values = f_regression(X_num, y)

anova_df = pd.DataFrame({
    "Feature": X_num.columns,
    "F_score": f_scores,
    "p_value": p_values
}).sort_values("p_value")

anova_df
# Out:
#                      Feature        F_score        p_value
# 12         avg_discount_used   16475.258367   0.000000e+00
# 13    impulse_purchase_ratio  220381.212946   0.000000e+00
# 15   avg_minutes_to_purchase    3808.867974   0.000000e+00
# 14    past_impulse_purchases   50290.642851   0.000000e+00
# 9            total_purchases    3334.503447   0.000000e+00
# 8   late_night_session_ratio    5366.121735   0.000000e+00
# 16              stress_level    5169.239306   0.000000e+00
# 1             monthly_income     724.024386  2.410859e-158
# 11        avg_purchase_value     287.317720   2.889574e-64
# 10               total_spent     188.202038   9.382849e-43
# 18        saving_habit_score      35.714915   2.299505e-09
# 17            mood_last_week      27.195964   1.845724e-07
# 4    num_product_page_visits      10.080930   1.499026e-03
# 6        num_checkout_visits       8.438559   3.675081e-03
# 3             total_sessions       1.085098   2.975649e-01
# 7        avg_time_on_product       0.762934   3.824162e-01
# 0                        age       0.665729   4.145484e-01
# 2           account_age_days       0.354363   5.516565e-01
# 5            num_cart_visits       0.093842   7.593502e-01

# %%
significant_numeric_features = anova_df[anova_df["p_value"] < 0.05]["Feature"].tolist()
significant_numeric_features
# Out:
# ['avg_discount_used',
#  'impulse_purchase_ratio',
#  'avg_minutes_to_purchase',
#  'past_impulse_purchases',
#  'total_purchases',
#  'late_night_session_ratio',
#  'stress_level',
#  'monthly_income',
#  'avg_purchase_value',
#  'total_spent',
#  'saving_habit_score',
#  'mood_last_week',
#  'num_product_page_visits',
#  'num_checkout_visits']

# %%
df["impulse_bin"] = pd.qcut(df[target], q=3, labels=[0, 1, 2])

le = LabelEncoder()
city_encoded = le.fit_transform(df["city"])

chi2_score, p_val = chi2(city_encoded.reshape(-1, 1), df["impulse_bin"])

print("Chi2:", chi2_score[0])
print("p-value:", p_val[0])
# Out:
# Chi2: 2.764252266119196
# p-value: 0.251044231801337

# %%
numeric_features = significant_numeric_features

categorical_features = [
    "gender",
    "default_payment_method",
    "device_preference"
]

# %%
def build_pipeline(numeric_features, categorical_features):

    num_transformer = Pipeline([
        ("scaler", StandardScaler())
    ])

    cat_transformer = Pipeline([
        ("onehot", OneHotEncoder(handle_unknown="ignore", sparse_output=False))
    ])

    preprocessor = ColumnTransformer(
        [
            ("num", num_transformer, numeric_features),
            ("cat", cat_transformer, categorical_features)
        ],
        remainder="drop"
    )

    return preprocessor

# %%
X = df[numeric_features + categorical_features]
y = df[target]

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=TEST_SIZE, random_state=RANDOM_SEED
)

X_train, X_val, y_train, y_val = train_test_split(
    X_train, y_train, test_size=VAL_SIZE, random_state=RANDOM_SEED
)

print("Train:", len(X_train))
print("Val  :", len(X_val))
print("Test :", len(X_test))
# Out:
# Train: 30000
# Val  : 10000
# Test : 10000

# %%
lgbm = LGBMRegressor(
    n_estimators=300,
    learning_rate=0.05,
    max_depth=7,
    num_leaves=31,
    subsample=0.8,
    colsample_bytree=0.8,
    min_child_samples=20,
    reg_alpha=0.01,
    reg_lambda=0.01,
    random_state=RANDOM_SEED,
    verbosity=-1
)

pipeline = Pipeline([
    ("preprocessor", build_pipeline(numeric_features, categorical_features)),
    ("model", lgbm)
])

# %%
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   ['avg_discount_used',
#                                                    'impulse_purchase_ratio',
#                                                    'avg_minutes_to_purchase',
#                                                    'past_impulse_purchases',
#                                                    'total_purchases',
#                                                    'late_night_session_ratio',
#                                                    'stress_level',
#                                                    'monthly_income',
#                                                    'avg_purchase_value',
#                                                    'total_spent',
#                                                    'saving_habit_score',
#                                                    'mo...
#                                                    'num_product_page_visits',
#                                                    'num_checkout_visits']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['gender',
#                                                    'default_payment_method',
#                                                    'device_preference'])])),
#                 ('model',
#                  LGBMRegressor(colsample_bytree=0.8, learning_rate=0.05,
#                                max_depth=7, n_estimators=300, random_state=42,
#                                reg_alpha=0.01, reg_lambda=0.01, subsample=0.8,
#                                verbosity=-1))])

# %%
def evaluate(y_true, y_pred, name="Set"):
    r2 = r2_score(y_true, y_pred)
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mae = mean_absolute_error(y_true, y_pred)
    mape = np.mean(np.abs((y_true - y_pred) / np.where(y_true != 0, y_true, 1))) * 100

    print(f"\n{name} Performance")
    print(f"R2   : {r2:.4f}")
    print(f"RMSE : {rmse:.4f}")
    print(f"MAE  : {mae:.4f}")
    print(f"MAPE : {mape:.2f}%")

    return r2, rmse, mae, mape

# %%
evaluate(y_train, pipeline.predict(X_train), "Train")
evaluate(y_val, pipeline.predict(X_val), "Validation")
evaluate(y_test, pipeline.predict(X_test), "Test")
# Out:
# Train Performance
# R2   : 0.9685
# RMSE : 2.9005
# MAE  : 2.3137
# MAPE : 8.63%
#
# Validation Performance
# R2   : 0.9637
# RMSE : 3.1293
# MAE  : 2.4978
# MAPE : 9.29%
#
# Test Performance
# R2   : 0.9621
# RMSE : 3.1560
# MAE  : 2.5091
# MAPE : 9.37%
# (0.9620803880003388,
#  np.float64(3.1559815070337485),
#  2.509109957359595,
#  np.float64(9.370953291688489))

# %%
# joblib.dump(pipeline, MODEL_OUT)
# print("✅ Model saved at:", MODEL_OUT.resolve())
# Out:
# ✅ Model saved at: C:\Users\Pegasus\Desktop\model_prac\models\lgbm_pipeline.joblib
